# %%
# !pip install pandas
# !pip install requests

# %% [markdown]
# Extraindo Dados da API IBGE

# %%
import requests
import pandas

def get_data(url):
    response = requests.get(url)
    return pandas.DataFrame(response.json())

get_data("https://servicodados.ibge.gov.br/api/v1/localidades/distritos")
